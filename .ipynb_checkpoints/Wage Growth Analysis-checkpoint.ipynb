# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

wages_2019 = pd.read_stata('epi_cpsorg_2019.dta')
wages_2020 = pd.read_stata('epi_cpsorg_2020.dta')
wages_2021 = pd.read_stata('epi_cpsorg_2021.dta')
wages_2022 = pd.read_stata('epi_cpsorg_2022.dta')

wages_19_abridged = wages_2019[['basicwgt', 'cmpwgt', 'famrel', 'faminc', 'hhid', 'hrhhid', 'hrhhid2', 
                                  'month', 'multjobs','orgwgt', 'personid', 'wage', 'wageotc','weekpay', 'wbhaom']]
wages_20_abridged = wages_2020[['basicwgt', 'cmpwgt', 'famrel', 'faminc', 'hhid', 'hrhhid', 'hrhhid2', 
                                  'month', 'multjobs','orgwgt', 'personid', 'wage', 'wageotc','weekpay', 'wbhaom']]
wages_21_abridged = wages_2021[['basicwgt','cmpwgt', 'famrel', 'faminc', 'hhid', 'hrhhid', 'hrhhid2', 
                                  'month', 'multjobs','orgwgt', 'personid', 'wage', 'wageotc','weekpay','wbhaom']]
wages_22_abridged = wages_2022[['basicwgt', 'cmpwgt','famrel', 'faminc', 'hhid', 'hrhhid', 'hrhhid2', 
                                  'month', 'multjobs', 'orgwgt','personid', 'wage', 'wageotc', 'weekpay','wbhaom']]

print(wages_22_abridged.head())
# Out:
#       basicwgt       cmpwgt                                       famrel  \
# 0  1531.265747  1531.265747                          Not a family member
# 1  2144.289795  2144.289795                             Reference person
# 2  1600.785034  1600.785034  Other relative (primary family & unrelated)
# 3  1808.955200  1808.955200                             Reference person
# 4  2335.305908  2335.305908                                       Spouse
#
#                                   faminc     hhid           hrhhid hrhhid2  \
# 0  $100,000 - $149,999 (2003m10-present)   5173.0  000110207755866   12111
# 1                      $30,000 - $34,999  13321.0  000110233098483   13111
# 2                      $30,000 - $34,999  13321.0  000110233098483   13111
# 3            $150,000+ (2003m10-present)  29372.0  000110435649045   13011
# 4            $150,000+ (2003m10-present)  29372.0  000110435649045   13011
#
#    month                         multjobs       orgwgt  personid    wage  \
# ...

# %%
wages_22_abridged['wage_null'] = wages_22_abridged['wage'].notnull()
wages_22_abridged['multjobs_null'] = wages_22_abridged['multjobs'].notnull()
# wages_22_abridged['wage_null'] = wages_22_abridged['wage'].notnull()
# wages_22_abridged['wage_null'] = wages_22_abridged['wage'].notnull()

# wages_22_abridged['wage_null'] = wages_22_abridged['wage'].notnull()
# wages_22_abridged['wage_null'] = wages_22_abridged['wage'].notnull()
# wages_22_abridged['wage_null'] = wages_22_abridged['wage'].notnull()
# wages_22_abridged['wage_null'] = wages_22_abridged['wage'].notnull()

# np.percentile(wages_22_abridged[wages_22_abridged['wage'].notnull()], [0.2, 0.4, 0.6, 0.8] )
# wages_22_abridged.loc[wages_22_abridged['wage'].notnull(), 'wage']
# print(wages_22_abridged['wage'].unique())
print(len(wages_22_abridged[wages_22_abridged['multjobs'].notnull()]))
print(len(wages_22_abridged[wages_22_abridged['wage'].notnull()]))
print(len(wages_22_abridged[wages_22_abridged['weekpay'].notnull()]))
print(len(wages_22_abridged[wages_22_abridged['basicwgt'].notnull()]))
print(len(wages_22_abridged[wages_22_abridged['orgwgt'].notnull()]))
print(len(wages_22_abridged[wages_22_abridged['month'] == 1]))
print(len(wages_22_abridged[wages_22_abridged['month'] == 1 & wages_22_abridged['cmpwgt'].notnull()]))
print(wages_22_abridged[wages_22_abridged['month'] == 1])
# Out:
# /var/folders/_v/rc7h94c52kxfc277kw_2jchc0000gn/T/ipykernel_888/4106637320.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wages_22_abridged['wage_null'] = wages_22_abridged['wage'].notnull()
# /var/folders/_v/rc7h94c52kxfc277kw_2jchc0000gn/T/ipykernel_888/4106637320.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wages_22_abridged['multjobs_null'] = wages_22_abridged['multjobs'].notnull()
# 578816
# 129495
# 129714
# 991759
# 251377
# 102656
# 83021
# ...
